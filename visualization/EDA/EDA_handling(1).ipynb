# %%
import pandas as pd

# %%
naver_movie = pd.read_csv("./04_naver_movie_review.csv")
naver_movie
# Out:
#       Unnamed: 0          name  Point
# 0              0        ...ing   8.87
# 1              1        0.0MHz   5.60
# 2              2      007 스카이폴   7.85
# 3              3       007 스펙터   7.56
# 4              4           10분   8.89
# ...          ...           ...    ...
# 1599        1599            히야   9.19
# 1600        1600         히어애프터   7.81
# 1601        1601            히트   9.10
# 1602        1602           히트맨   7.18
# 1603        1603  힘을 내요, 미스터 리   7.60
#
# [1604 rows x 3 columns]

# %%
kobis_movie = pd.read_csv("./datas/kobis_movie.csv",  parse_dates=[3])
kobis_movie
# Out:
#      Unnamed: 0        Movie  Audience        Open  Screen watchGradeNm  \
# 0      20192193           도굴    565469  2020-11-04    1634     12세이상관람가
# 1      20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가
# 2      20199816           담보   1702252  2020-09-29     407     12세이상관람가
# 3      20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가
# 4      20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가
# ..          ...          ...       ...         ...     ...          ...
# 655    20158806          용주골       306  2015-11-19      20      청소년관람불가
# 656    20157464          더 폰   1593592  2015-10-22       7     15세이상관람가
# 657    20158701      세상끝의 사랑      3080  2015-11-12      97      청소년관람불가
# 658    20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가
# 659    20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가
#
#      genres
# 0        범죄
# 1       드라마
# 2       드라마
# 3        공연
# 4        범죄
# ..      ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from matplotlib import font_manager

f_path = "C:\Windows\Fonts\malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %%
kobis_movie = kobis_movie.rename(columns={'Unnamed: 0' : 'Code'})
kobis_movie = kobis_movie.set_index('Code')
kobis_movie
# Out:
#                 Movie  Audience        Open  Screen watchGradeNm  genres
# Code
# 20192193           도굴    565469  2020-11-04    1634     12세이상관람가      범죄
# 20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가     드라마
# 20199816           담보   1702252  2020-09-29     407     12세이상관람가     드라마
# 20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가      공연
# 20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가      범죄
# ...               ...       ...         ...     ...          ...     ...
# 20158806          용주골       306  2015-11-19      20      청소년관람불가     드라마
# 20157464          더 폰   1593592  2015-10-22       7     15세이상관람가     스릴러
# 20158701      세상끝의 사랑      3080  2015-11-12      97      청소년관람불가  멜로/로맨스
# 20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가      범죄
# 20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가     드라마
#
# [660 rows x 6 columns]

# %%
dele = kobis_movie[kobis_movie['genres'] == '성인물(에로)'].index
kobis_movie.drop(dele, inplace=True)
kobis_movie
# Out:
#                 Movie  Audience        Open  Screen watchGradeNm  genres
# Code
# 20192193           도굴    565469  2020-11-04    1634     12세이상관람가      범죄
# 20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가     드라마
# 20199816           담보   1702252  2020-09-29     407     12세이상관람가     드라마
# 20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가      공연
# 20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가      범죄
# ...               ...       ...         ...     ...          ...     ...
# 20158806          용주골       306  2015-11-19      20      청소년관람불가     드라마
# 20157464          더 폰   1593592  2015-10-22       7     15세이상관람가     스릴러
# 20158701      세상끝의 사랑      3080  2015-11-12      97      청소년관람불가  멜로/로맨스
# 20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가      범죄
# 20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가     드라마
#
# [651 rows x 6 columns]

# %%
dele = kobis_movie[(kobis_movie['watchGradeNm'] == '청소년관람불가') & (kobis_movie['genres'] == '멜로/로맨스')].index
kobis_movie.drop(dele, inplace=True)
kobis_movie
# Out:
#                 Movie  Audience        Open  Screen watchGradeNm genres
# Code
# 20192193           도굴    565469  2020-11-04    1634     12세이상관람가     범죄
# 20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가    드라마
# 20199816           담보   1702252  2020-09-29     407     12세이상관람가    드라마
# 20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가     공연
# 20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가     범죄
# ...               ...       ...         ...     ...          ...    ...
# 20157465         그놈이다   1045218  2015-10-28      35     15세이상관람가    스릴러
# 20158806          용주골       306  2015-11-19      20      청소년관람불가    드라마
# 20157464          더 폰   1593592  2015-10-22       7     15세이상관람가    스릴러
# 20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가     범죄
# 20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가    드라마
#
# [591 rows x 6 columns]

# %%
del1 = kobis_movie[(kobis_movie['Audience'].astype('int') < 1000) & (kobis_movie['watchGradeNm'] == '청소년관람불가')].index
kobis_movie.drop(del1, inplace=True)
kobis_movie
# Out:
#                 Movie  Audience        Open  Screen watchGradeNm genres
# Code
# 20192193           도굴    565469  2020-11-04    1634     12세이상관람가     범죄
# 20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가    드라마
# 20199816           담보   1702252  2020-09-29     407     12세이상관람가    드라마
# 20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가     공연
# 20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가     범죄
# ...               ...       ...         ...     ...          ...    ...
# 20145501         돌연변이    100498  2015-10-22       7     12세이상관람가    드라마
# 20157465         그놈이다   1045218  2015-10-28      35     15세이상관람가    스릴러
# 20157464          더 폰   1593592  2015-10-22       7     15세이상관람가    스릴러
# 20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가     범죄
# 20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가    드라마
#
# [576 rows x 6 columns]

# %%
kobis_movie.dropna(inplace=True)
kobis_movie
# Out:
#                 Movie  Audience        Open  Screen watchGradeNm genres
# Code
# 20192193           도굴    565469  2020-11-04    1634     12세이상관람가     범죄
# 20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가    드라마
# 20199816           담보   1702252  2020-09-29     407     12세이상관람가    드라마
# 20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가     공연
# 20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가     범죄
# ...               ...       ...         ...     ...          ...    ...
# 20145501         돌연변이    100498  2015-10-22       7     12세이상관람가    드라마
# 20157465         그놈이다   1045218  2015-10-28      35     15세이상관람가    스릴러
# 20157464          더 폰   1593592  2015-10-22       7     15세이상관람가    스릴러
# 20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가     범죄
# 20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가    드라마
#
# [420 rows x 6 columns]

# %%
kobis_movie['Open'].infer_objects()
# Out:
# Code
# 20192193    2020-11-04
# 20197121    2020-10-21
# 20199816    2020-09-29
# 20208508    2020-10-22
# 20194424    2020-10-15
#                ...
# 20145501    2015-10-22
# 20157465    2015-10-28
# 20157464    2015-10-22
# 20142855    2015-10-08
# 20149961    2015-10-28
# Name: Open, Length: 420, dtype: object

# %%
kobis_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420 entries, 20192193 to 20149961
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie         420 non-null    object
#  1   Audience      420 non-null    int64
#  2   Open          420 non-null    object
#  3   Screen        420 non-null    int64
#  4   watchGradeNm  420 non-null    object
#  5   genres        420 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.0+ KB

# %%
kobis_movie.to_csv('./kobis_movie(420).csv', sep=',', encoding='utf-8')

# %%
plt.figure(figsize=(10,8))
kobis_movie['genres'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10,8))
kobis_movie['watchGradeNm'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
kobis_movie
# Out:
#                 Movie  Audience        Open  Screen watchGradeNm genres
# Code
# 20192193           도굴    565469  2020-11-04    1634     12세이상관람가     범죄
# 20197121   삼진그룹 영어토익반   1257444  2020-10-21    1080     12세이상관람가    드라마
# 20199816           담보   1702252  2020-09-29     407     12세이상관람가    드라마
# 20208508  미스터트롯: 더 무비    140594  2020-10-22     159        전체관람가     공연
# 20194424       소리도 없이    401759  2020-10-15     126     15세이상관람가     범죄
# ...               ...       ...         ...     ...          ...    ...
# 20145501         돌연변이    100498  2015-10-22       7     12세이상관람가    드라마
# 20157465         그놈이다   1045218  2015-10-28      35     15세이상관람가    스릴러
# 20157464          더 폰   1593592  2015-10-22       7     15세이상관람가    스릴러
# 20142855       성난 변호사   1127747  2015-10-08      21     15세이상관람가     범죄
# 20149961  미안해 사랑해 고마워     50571  2015-10-28       5     15세이상관람가    드라마
#
# [410 rows x 6 columns]
