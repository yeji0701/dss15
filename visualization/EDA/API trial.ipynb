# %%
import requests
import json
import datetime as dt
import pandas as pd
from matplotlib import pyplot

# %%
key = ""

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36"
session = requests.Session()
session.headers.update( {'User-agent': user_agent, 'referer': None} )

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={date}&multiMovieYn={N}&repNationCd={K}"
url
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={date}&multiMovieYn={N}&repNationCd={K}'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
today = dt.datetime.now()                       # 오늘날짜
delta = dt.timedelta(days = -1)                 # 하루 전을 의미하는 timedelta객체
yesterday = today + delta                       # 오늘 날짜와 timedelta 연산
yesterday_str = yesterday.strftime("%Y%m%d")    # yyyymmdd 형식 문자열로 변환
yesterday_str
# Out:
# '20201102'

# %%
api_url = url.format(key=key, date=yesterday_str, N='N', K="K")
api_url
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=722bc4cdc30e62cd768bd487a8ff7aac&targetDt=20201102&multiMovieYn=N&repNationCd=K'

# %%
r = session.get(api_url)

if r.status_code != 200:
    print("[%d Error] %s" % (r.status_code, r.reason))
    quit()

r.encoding = "utf-8"

# %%
daily_boxoffice_dict = json.loads(r.text)
daily_boxoffice_dict
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20201102~20201102',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20197121',
#     'movieNm': '삼진그룹 영어토익반',
#     'openDt': '2020-10-21',
#     'salesAmt': '360957640',
#     'salesShare': '65.6',
#     'salesInten': '-1028600360',
#     'salesChange': '-74',
#     'salesAcc': '8543707520',
#     'audiCnt': '40880',
#     'audiInten': '-105466',
#     'audiChange': '-72.1',
#     'audiAcc': '972587',
#     'scrnCnt': '1438',
#     'showCnt': '5157'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20199816',
#     'movieNm': '담보',
#     'openDt': '2020-09-29',
#     'salesAmt': '51496890',
#     'salesShare': '9.4',
#     'salesInten': '-148617580',
#     'salesChange': '-74.3',
#     'salesAcc': '14338670640',
#     'audiCnt': '5929',
#     'audiInten': '-15967',
# ...

# %%
daily_boxoffice_df = DataFrame(daily_boxoffice_dict['boxOfficeResult']['dailyBoxOfficeList'])
daily_boxoffice_df
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd                    movieNm  \
# 0    1    1         0           OLD  20197121                 삼진그룹 영어토익반
# 1    2    2         0           OLD  20199816                         담보
# 2    3    3         0           NEW  20192193                         도굴
# 3    4    4        -1           OLD  20194424                     소리도 없이
# 4    5    5         0           OLD  20208508                미스터트롯: 더 무비
# 5    6    6        -2           OLD  20209304           다만 악에서 구하소서 파이널컷
# 6    7    7        -1           OLD  20206826  그대, 고맙소 : 김호중 생애 첫 팬미팅 무비
# 7    8    8         0           OLD  20196675                    젊은이의 양지
# 8    9    9        -2           OLD  20206588       극장판 미니특공대: 햄버거괴물의 습격
# 9   10   10        -1           OLD  20030094                    원더풀 데이즈
#
#        openDt   salesAmt salesShare   salesInten salesChange     salesAcc  \
# 0  2020-10-21  360957640       65.6  -1028600360         -74   8543707520
# ...

# %%
tmp_df = daily_boxoffice_df.rename(columns={"movieNm":"Movie", "openDt":"Release", "audiAcc":"Audience", "scrnCnt":"Screen"})
tmp_df = tmp_df.filter(["Movie", "Release", "Audience", "Screen"])
tmp_df
# Out:
#                        Movie     Release Audience Screen
# 0                 삼진그룹 영어토익반  2020-10-21   972587   1438
# 1                         담보  2020-09-29  1671193    520
# 2                         도굴  2020-11-04     6660     47
# 3                     소리도 없이  2020-10-15   395438    408
# 4                미스터트롯: 더 무비  2020-10-22   129066    218
# 5           다만 악에서 구하소서 파이널컷  2020-10-28    28981    369
# 6  그대, 고맙소 : 김호중 생애 첫 팬미팅 무비  2020-09-29   101524     51
# 7                    젊은이의 양지  2020-10-28     3752     80
# 8       극장판 미니특공대: 햄버거괴물의 습격  2020-09-30    53900     11
# 9                    원더풀 데이즈  2003-07-17     1028     32

# %%
name_dict = {}
for i, v in enumerate(list(tmp_df['Movie'])):
    name_dict[i] = v
    
tmp_df.drop('Movie', axis=1, inplace=True)
daily_rank_df
# Out:
#                               Release Audience Screen
# 삼진그룹 영어토익반                 2020-10-21   972587   1438
# 담보                         2020-09-29  1671193    520
# 도굴                         2020-11-04     6660     47
# 소리도 없이                     2020-10-15   395438    408
# 미스터트롯: 더 무비                2020-10-22   129066    218
# 다만 악에서 구하소서 파이널컷           2020-10-28    28981    369
# 그대, 고맙소 : 김호중 생애 첫 팬미팅 무비  2020-09-29   101524     51
# 젊은이의 양지                    2020-10-28     3752     80
# 극장판 미니특공대: 햄버거괴물의 습격       2020-09-30    53900     11
# 원더풀 데이즈                    2003-07-17     1028     32

# %%
    key = ""
    
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36"
    session = requests.Session()
    session.headers.update( {'User-agent': user_agent, 'referer': None} )
    
    url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={date}&multiMovieYn={N}&repNationCd={K}"
    
    response = requests.get(url)
    
    today = dt.datetime.now()                       
    delta = dt.timedelta(days = -1)                 
    yesterday = today + delta                       
    yesterday_str = yesterday.strftime("%Y%m%d")    
    yesterday_str
    
    api_url = url.format(key=key, date=targetDt, N='N', K="K")
    
    r = session.get(api_url)

    if r.status_code != 200:
        print("[%d Error] %s" % (r.status_code, r.reason))
        quit()
    r.encoding = "utf-8"
    
    daily_boxoffice_dict = json.loads(r.text)
    
    daily_boxoffice_df = DataFrame(daily_boxoffice_dict['boxOfficeResult']['dailyBoxOfficeList'])
    
    
    tmp_df = daily_boxoffice_df.rename(columns={"movieNm":"Movie", "openDt":"Release", "audiAcc":"Audience", "scrnCnt":"Screen"})
    tmp_df = tmp_df.filter(["Movie", "Release", "Audience", "Screen"])
    
    tmp_df
# Out:
#                        Movie     Release Audience Screen
# 0                 삼진그룹 영어토익반  2020-10-21   436424   1487
# 1                         담보  2020-09-29  1596917    570
# 2                미스터트롯: 더 무비  2020-10-22   100345    365
# 3                     소리도 없이  2020-10-15   357778    580
# 4  그대, 고맙소 : 김호중 생애 첫 팬미팅 무비  2020-09-29    95720     51
# 5                 사당동 더하기 33                  282      1
# 6          브레이크 더 사일런스: 더 무비  2020-09-24   130450     47
# 7                      오! 문희  2020-09-02   345921      2
# 8                  웰컴 투 X-월드  2020-10-29      801      1
# 9                    섹스 소녀 5  2020-10-27       60      1
