# %%
import pandas as pd

# %%
df = pd.read_csv('./Rev5_movie.csv', index_col=[0])

# %%
df.drop()
# Out:
#      Unnamed: 0.1      Code        Movie  Audience  Screen genres AgeRate  \
# 0               0  20192193           도굴   565.469    1634     범죄  청소년관람가
# 1               1  20197121   삼진그룹 영어토익반  1257.444    1080    드라마  청소년관람가
# 2               2  20199816           담보  1702.252     407    드라마  청소년관람가
# 3               3  20208508  미스터트롯: 더 무비   140.594     159     공연   전체관람가
# 4               4  20194424       소리도 없이   401.759     126     범죄  청소년관람가
# ..            ...       ...          ...       ...     ...    ...     ...
# 416           416  20145501         돌연변이   100.498       7    드라마  청소년관람가
# 417           417  20157465         그놈이다  1045.218      35    스릴러  청소년관람가
# 418           418  20157464          더 폰  1593.592       7    스릴러  청소년관람가
# 419           419  20142855       성난 변호사  1127.747      21     범죄  청소년관람가
# 420           420  20149961  미안해 사랑해 고마워    50.571       5    드라마  청소년관람가
#
#      month  year  four_month  year_cat  Point  Top10배우  Age_Rate
# ...
