# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')


from matplotlib import font_manager
f_path = "C:\Windows\Fonts\malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import requests
import urllib
import time

# %%
html = 'https://kin.naver.com/search/list.nhn?query={key_word}&page={num}'

req = Request(html.format(num=1, key_word=urllib.parse.quote('크리스마스 선물')))
req.add_header('Referer', 'http://www.naver.com')

response = urlopen(req)

soup = BeautifulSoup(response, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="크리스마스 선물의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20201216152804/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20201216152804/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20201216152804/css/min/other.css" rel="stylesheet" type="text/css"/>
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# ...

# %%
links = soup.find_all('dt')
links[0].a['href']
# Out:
# 'https://kin.naver.com/qna/detail.nhn?d1id=6&dirId=6130202&docId=376634871&qb=7YGs66as7Iqk66eI7IqkIOyEoOusvA==&enc=utf8§ion=kin&rank=1&search_sort=0&spq=1'

# %%
html = links[0].a['href']
r = requests.get(links[0].a['href'])
soup_tmp = BeautifulSoup(r.text, 'html.parser')
soup_tmp
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="width=1024" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="none" name="msapplication-config">
# <meta content="index,nofollow" name="robots">
# <meta content="크리스마스 선물" property="og:title">
# <meta content="https://kin.naver.com/qna/detail.nhn?d1id=6&amp;dirId=6130202&amp;docId=376634871&amp;qb=7YGs66as7Iqk66eI7IqkIOyEoOusvA==&amp;enc=utf8%C2%A7ion=kin&amp;rank=1&amp;search_sort=0&amp;spq=1" property="og:url">
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="크리스마스선물로 케이스받을건데 갤럭시 젤케이스 이쁜거있으면 알려주세요(내공100)" property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <title>
# ...

# %%
soup_tmp.find_all('div', '_endContentsText')
# Out:
# [<div class="_endContentsText c-heading-answer__content-user"><div class="se-viewer se-theme-default" lang="ko-KR"> <!-- SE_DOC_HEADER_START --> <!--@CONTENTS_HEADER--> <!-- SE_DOC_HEADER_END --> <div class="se-main-container"> <div class="se-component se-text se-l-default" id="SE-66aafefe-52cd-4668-a4e0-7542ae735c87"> <div class="se-component-content"> <div class="se-section se-section-text se-l-default"> <div class="se-module se-module-text"> <!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align- " id="SE-6236fc2d-cb44-4706-8f49-436bb7abd83b" style=""><span class="se-fs- se-ff- " id="SE-569a7fd0-4220-444f-b7f6-5793ded9eaec" style="">크리스마스 선물로 젤케이스 고민중이시군요!</span></p><!-- } SE-TEXT --><!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align- " id="SE-ff63bbd8-dfc3-4fba-83ab-c82287d52879" style=""><span class="se-fs- se-ff- " id="SE-ce6940af-cb4b-4733-abe6-f86fa85b6e27" style="">​</span></p><!-- } SE-TEXT --><!-- SE-TEXT { --><p class="se-text-paragraph s
# ...

# %%
contents = []

search_result = soup_tmp.find_all('div', '_endContentsText')

for each in search_result:
    contents.append(each.get_text())
contents
# Out:
# ['         크리스마스 선물로 젤케이스 고민중이시군요!\u200b몇가지 상품 추천해드릴게요!\u200bhttps://bit.ly/2WG51le              두리케이스 [1+1] 디자인 젤리케이스 전기종 휴대폰 케이스 COUPANG bit.ly            \u200bhttps://bit.ly/3nL2QIL              [1+1] 스마트폰 투명 젤리케이스 COUPANG bit.ly            \u200bhttps://bit.ly/2Je32Bn              키스해링 스키누 젤하드 시즌2 탈부착 핸드폰 목걸이 케이스 COUPANG bit.ly            \u200bhttps://bit.ly/38zPFV0              쿠디스 카드포켓 젤리 투명 휴대폰 케이스 2p COUPANG bit.ly            \u200bhttps://bit.ly/3h8NRWM              소프트 무광 실리콘 휴대폰 케이스 COUPANG bit.ly            \u200b\u200b추천상품이 마음에 드셨나요?\u200b모쪽록 원하시는 상품 찾으시길 바랄게요!!\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b파트너스 활동을 통해 일정액의 수수료를 제공받을 수 있음     ',
# ...

# %%
# !pip install tqdm

# %%
from tqdm.notebook import tqdm

present_candi_text = []

for each_link in tqdm(links):
    r = requests.get(each_link.a['href'])
    soup_tmp = BeautifulSoup(r.text, 'html.parser')
    search_result = soup_tmp.find_all('div', '_endContentsText')
    
    time.sleep(0.1)
    
    for each in search_result:
        present_candi_text.append(each.get_text())

# %%
present_candi_text
# Out:
# ['         크리스마스 선물로 젤케이스 고민중이시군요!\u200b몇가지 상품 추천해드릴게요!\u200bhttps://bit.ly/2WG51le              두리케이스 [1+1] 디자인 젤리케이스 전기종 휴대폰 케이스 COUPANG bit.ly            \u200bhttps://bit.ly/3nL2QIL              [1+1] 스마트폰 투명 젤리케이스 COUPANG bit.ly            \u200bhttps://bit.ly/2Je32Bn              키스해링 스키누 젤하드 시즌2 탈부착 핸드폰 목걸이 케이스 COUPANG bit.ly            \u200bhttps://bit.ly/38zPFV0              쿠디스 카드포켓 젤리 투명 휴대폰 케이스 2p COUPANG bit.ly            \u200bhttps://bit.ly/3h8NRWM              소프트 무광 실리콘 휴대폰 케이스 COUPANG bit.ly            \u200b\u200b추천상품이 마음에 드셨나요?\u200b모쪽록 원하시는 상품 찾으시길 바랄게요!!\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b파트너스 활동을 통해 일정액의 수수료를 제공받을 수 있음     ',
# ...

# %%
import nltk
from konlpy.tag import Okt
t = Okt()

present_text = ''

for each_line in present_candi_text:
    present_text = present_text + each_line + '\n'

# %%
tokens_ko = t.nouns(present_text)
tokens_ko
# Out:
# ['크리스마스',
#  '선물',
#  '젤',
#  '케이스',
#  '고민',
#  '군',
#  '가지',
#  '상품',
#  '추천',
#  '두리',
#  '케이스',
#  '디자인',
#  '젤리',
#  '케이스',
#  '전기',
#  '종',
#  '휴대폰',
#  '케이스',
#  '스마트폰',
#  '투명',
#  '젤리',
#  '케이스',
#  '키스',
#  '링',
#  '스키',
#  '누',
#  '젤',
#  '하드',
#  '시즌',
#  '탈',
#  '부착',
#  '핸드폰',
#  '목걸이',
#  '케이스',
#  '쿠',
#  '디스',
#  '카드',
#  '포켓',
#  '젤리',
#  '투명',
#  '휴대폰',
#  '케이스',
#  '소프트',
#  '무광',
#  '실리콘',
#  '휴대폰',
#  '케이스',
#  '추천',
#  '상품',
#  '마음',
#  '쪽록',
#  '상품',
#  '파트너',
#  '스',
#  '활동',
#  '통해',
#  '정액',
#  '수수료',
#  '제공',
#  '수',
#  '크리스마스',
#  '선물',
#  '가지',
#  '추천',
#  '사람',
#  '만족도',
#  '이',
#  '린',
#  '별빛',
#  '트리',
#  '무드등',
#  '디씨',
#  '휴대',
#  '용',
#  '보조',
#  '배터리',
#  '겸용',
#  '충전',
#  '손',
#  '난로',
#  '유엠투',
#  '무드등',
#  '조명',
#  '고속',
#  '무선',
#  '충전기',
#  '후기',
#  '직접',
#  '결정',
#  '가격',
#  '부담',
#  '만족도',
#  '파트너',
#  '스',
#  '추가',
#  '수익',
#  '수',
#  '정도',
#  '샵',
#  '캐릭터',
#  '수면',
#  '양말',
#  '겨울',
#  '양말',
#  '케이스',
#  '포함',
#  '인용',
#  '아동',
#  '용',
# ...

# %%
ko = nltk.Text(tokens_ko, name='크리스마스 선물')
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# 1968
# 711

# %%
ko = nltk.Text(tokens_ko, name='크리스마스 선물')
ko.vocab().most_common(100)
# Out:
# [('선물', 87),
#  ('수', 35),
#  ('추천', 34),
#  ('크리스마스', 31),
#  ('세트', 28),
#  ('디자인', 18),
#  ('용', 18),
#  ('과자', 18),
#  ('목걸이', 16),
#  ('파트너', 16),
#  ('가격', 16),
#  ('것', 16),
#  ('케이스', 15),
#  ('손', 15),
#  ('난로', 15),
#  ('제품', 15),
#  ('활동', 13),
#  ('이', 13),
#  ('배터리', 13),
#  ('겨울', 13),
#  ('사랑', 13),
#  ('양말', 12),
#  ('향수', 12),
#  ('마음', 11),
#  ('수수료', 11),
#  ('무드등', 11),
#  ('목도리', 11),
#  ('가지', 10),
#  ('스', 10),
#  ('제공', 10),
#  ('만족도', 10),
#  ('토파즈', 10),
#  ('거', 10),
#  ('상품', 9),
#  ('보조', 9),
#  ('직접', 9),
#  ('포함', 9),
#  ('가성', 9),
#  ('비', 9),
#  ('여자친구', 9),
#  ('요', 9),
#  ('전기', 8),
#  ('사람', 8),
#  ('부담', 8),
#  ('채택', 8),
#  ('그', 8),
#  ('저', 8),
#  ('제', 8),
#  ('여자', 8),
#  ('충전', 7),
#  ('수면', 7),
#  ('바비', 7),
#  ('답변', 7),
#  ('분', 7),
#  ('이벤트', 7),
#  ('하트', 7),
#  ('남자', 7),
#  ('휴대', 6),
#  ('겸용', 6),
#  ('후기', 6),
#  ('추가', 6),
#  ('샵', 6),
#  ('캐릭터', 6),
#  ('인용', 6),
#  ('아동', 6),
#  ('미스', 6),
#  ('토리', 6),
#  ('빅사', 6),
# ...

# %%
ko.similar('선물')
# Out:
# 만큼

# %%
stop_words = ['한', '수', '은', '들', '!', '도', '이', '\u200b', '을', '에', ',', '.', '[', ']', '~', '는', '것', '요', '제', '수',
             '것', '뼘', '제', '요', '해', '분', '때문', '더', '줄']
tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]
ko = nltk.Text(tokens_ko, name='여자 친구 선물')
ko.vocab().most_common(50)
# Out:
# [('선물', 87),
#  ('추천', 34),
#  ('크리스마스', 31),
#  ('세트', 28),
#  ('디자인', 18),
#  ('용', 18),
#  ('과자', 18),
#  ('목걸이', 16),
#  ('파트너', 16),
#  ('가격', 16),
#  ('케이스', 15),
#  ('손', 15),
#  ('난로', 15),
#  ('제품', 15),
#  ('활동', 13),
#  ('배터리', 13),
#  ('겨울', 13),
#  ('사랑', 13),
#  ('양말', 12),
#  ('향수', 12),
#  ('마음', 11),
#  ('수수료', 11),
#  ('무드등', 11),
#  ('목도리', 11),
#  ('가지', 10),
#  ('스', 10),
#  ('제공', 10),
#  ('만족도', 10),
#  ('토파즈', 10),
#  ('거', 10),
#  ('상품', 9),
#  ('보조', 9),
#  ('직접', 9),
#  ('포함', 9),
#  ('가성', 9),
#  ('비', 9),
#  ('여자친구', 9),
#  ('전기', 8),
#  ('사람', 8),
#  ('부담', 8),
#  ('채택', 8),
#  ('그', 8),
#  ('저', 8),
#  ('여자', 8),
#  ('충전', 7),
#  ('수면', 7),
#  ('바비', 7),
#  ('답변', 7),
#  ('이벤트', 7),
#  ('하트', 7)]

# %%
plt.figure(figsize=(10,12))
ko.plot(50);

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(300)

wordcloud = WordCloud(font_path=f_path, relative_scaling=0.5, background_color='white').generate_from_frequencies(dict(data))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off');

# %%
from wordcloud import ImageColorGenerator

mask = np.array(Image.open('./datas/09. heart.jpg'))
image_colors = ImageColorGenerator(mask)

# %%
data = ko.vocab().most_common(200)

wordcloud = WordCloud(font_path=f_path, relative_scaling=0.1, mask=mask, background_color='white',
                     min_font_size=1, max_font_size=100).generate_from_frequencies(dict(data))
default_colors = wordcloud.to_array()
plt.figure(figsize=(12,12))
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis('off');
