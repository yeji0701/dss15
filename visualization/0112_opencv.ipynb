# %%
import matplotlib.pyplot as plt
import cv2

# %%
src = cv2.imread('./datas/airplane.bmp', cv2.IMREAD_COLOR)
plt.imshow(src);

# %%
mask = cv2.imread('./datas/mask_plane.bmp',cv2.IMREAD_GRAYSCALE)
plt.imshow(mask, cmap='gray');

# %%
dst = cv2.imread('./datas/field.bmp', cv2.IMREAD_COLOR)
plt.imshow(dst);

# %%
plt.imshow(cv2.copyTo(src, mask, dst));

# %%
imgBGR = cv2.imread('./datas/test.sw.jpg')
plt.axis('off')
plt.imshow(imgBGR)
plt.show()

# %%
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(imgRGB)
plt.show()

# %%
imgGray = cv2.imread('./datas/test.sw.jpg', cv2.IMREAD_GRAYSCALE)
plt.axis('off')
plt.imshow(imgGray, cmap='gray')
plt.show()

# %%
imgRGB.ndim
# Out:
# 3

# %%
imgRGB.shape, imgRGB.size, imgRGB.dtype
# Out:
# ((442, 658, 3), 872508, dtype('uint8'))

# %%
import numpy as np

img = np.full((400, 400, 3), 255, np.uint8)

cv2.line(img, (50, 50), (200, 50), (0, 0, 255), 5)
cv2.line(img, (50, 60), (150, 160), (0, 0, 128))
plt.imshow(img);

# %%
cv2.rectangle(img, (50, 200, 150, 100), (0, 255, 0), 2)
cv2.rectangle(img, (70, 220), (180, 280), (0, 128, 0), -1)
plt.imshow(img);

# %%
cv2.circle(img, (300, 100), 30, (255, 255, 0), -1, cv2.LINE_AA)
cv2.circle(img, (300, 100), 60, (255, 0, 0), 3, cv2.LINE_AA)
pts = np.array([[250, 200], [300, 200], [350, 300], [250, 300]])
cv2.polylines(img, [pts], True, (255, 0, 255), 2)
plt.imshow(img);

# %%
text = 'hello OpenCV' + cv2.__version__
cv2.putText(img, text, (50, 350), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 1, cv2.LINE_AA)
plt.imshow(img);
