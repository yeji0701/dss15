# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.4MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 9.6MB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/de/af/93f92b38ec1ff3091cd38982ed19cea2800fefb609b5801c41fc43c0781e/JPype1-1.2.1-cp36-cp36m-manylinux2010_x86_64.whl (457kB)
#      |████████████████████████████████| 460kB 48.0MB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/67/c3/6bed87f3b1e5ed2f34bd58bf7978e308c86e255193916be76e5a5ce5dfca/tweepy-3.10.0-py2.py3-none-any.whl
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: beautifulsoup4, JPype1, tweepy, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-1.2.1 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2 tweepy-3.10.0

# %%
import random
import tensorflow as tf
from konlpy.tag import Okt

EPOCHS = 200
NUM_WORDS = 2000

# %%
class Encoder(tf.keras.Model):
  def __init__(self):
    super(Encoder, self).__init__()
    self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
    self.lstm = tf.keras.layers.LSTM(512, return_state=True)
  
  def call(self, x, training=False, mask=None):
    x = self.emb(x)
    _, h, c = self.lstm(x)
    return h,c

# %%
class Decoder(tf.keras.Model):
  def __init__(self):
    super(Decoder, self).__init__()
    self.emb= tf.keras.layers.Embedding(NUM_WORDS, 64)
    self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)
    self.dense = tf.keras.layers.Dense(NUM_WORDS, activation='softmax')

  def call(self, inputs, training=False, mask=None):
    x, h, c = inputs
    x = self.emb(x)
    x, h, c = self.lstm(x, initial_state=[h,c])
    return self.dense(x), h, c

# %%
class Seq2seq(tf.keras.Model):
  def __init__(self, sos, eos):
    super(Seq2seq, self).__init__()
    self.enc = Encoder()
    self.dec = Decoder()
    self.sos = sos
    self.eos = eos
  def call(self, inputs, training=False, mask=None):
    if training is True:
      x, y = inputs
      h, c = self.enc(x)
      y, _, _ = self.dec((y, h, c))
      return y
    else:
      x = inputs
      h, c = self.enc(x)
      y = tf.convert_to_tensor(self.sos)
      y = tf.reshape(y, (1, 1))
      seq = tf.TensorArray(tf.int32, 64)
      for idx in tf.range(64):
        y, h, c = self.dec([y, h, c])
        y = tf.cast(tf.argmax(y, axis=-1), dtype=tf.int32)
        y = tf.reshape(y, (1, 1))
        seq = seq.write(idx, y)
        if y == self.eos:
          break
      return tf.reshape(seq.stack(), (1, 64))

# %%
@tf.function
def train_step(model, inputs, labels, loss_object, optimizer, train_loss, train_accuracy):
  output_labels = labels[:, 1:]
  shifted_labels = labels[:, :-1]
  with tf.GradientTape() as tape:
    predictions = model([inputs, shifted_labels], training=True)
    loss = loss_object(output_labels, predictions)
  gradients = tape.gradient(loss, model.trainable_variables)

  optimizer.apply_gradients(zip(gradients, model.trainable_variables))
  train_loss(loss)
  train_accuracy(output_labels, predictions)

@tf.function
def test_step(model, inputs):
  return model(inputs, training=False)

# %%
dataset_file = '/content/drive/MyDrive/Colab Notebooks/datas/chatbot_data.csv' 
okt = Okt()

with open(dataset_file, 'r') as file:
  lines = file.readlines()
  seq = [' '.join(okt.morphs(line)) for line in lines]

questions = seq[::2]
answers = ['\t ' + lines for lines in seq[1::2]]

num_sample = len(questions)

perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

train_q = list()
train_a = list()
test_q = list()
test_a = list()

for idx, qna in enumerate(zip(questions, answers)):
  q, a = qna
  if perm[idx] > num_sample//5:
    train_q.append(q)
    train_a.append(a)
  else:
    test_q.append(q)
    test_a.append(a)
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~')
tokenizer.fit_on_texts(train_q + train_a)

train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

x_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq, value=0, padding='pre', maxlen=64)
y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq, value=0, padding='post', maxlen=65)

x_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq, value=0, padding='pre', maxlen=64)
y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq, value=0, padding='post', maxlen=65)

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(10000).batch(32).prefetch(1024)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(1).prefetch(1024)

# %%
model = Seq2seq(sos=tokenizer.word_index['\t'], eos=tokenizer.word_index['\n'])

loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %%
for epoch in range(EPOCHS):
  for seqs, labels in train_ds:
    train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)

  template = 'Epoch {}, Loss: {}, Accuracy: {}'
  print(template.format(epoch + 1, train_loss.result(), train_accuracy.result() * 100))

  train_loss.reset_states()
  train_accuracy.reset_states()
# Out:
# Epoch 1, Loss: 3.094630002975464, Accuracy: 83.20801544189453
# Epoch 2, Loss: 0.6022385358810425, Accuracy: 90.88346099853516
# Epoch 3, Loss: 0.5638185143470764, Accuracy: 91.0753402709961
# Epoch 4, Loss: 0.5472832918167114, Accuracy: 91.13408660888672
# Epoch 5, Loss: 0.5439242124557495, Accuracy: 91.1536636352539
# Epoch 6, Loss: 0.5402533411979675, Accuracy: 91.11058807373047
# Epoch 7, Loss: 0.534101665019989, Accuracy: 91.09100341796875
# Epoch 8, Loss: 0.5339129567146301, Accuracy: 91.17716217041016
# Epoch 9, Loss: 0.5275033712387085, Accuracy: 91.14974975585938
# Epoch 10, Loss: 0.522671103477478, Accuracy: 91.18890380859375
# Epoch 11, Loss: 0.5094152092933655, Accuracy: 91.19282531738281
# Epoch 12, Loss: 0.5102260112762451, Accuracy: 91.26331329345703
# Epoch 13, Loss: 0.4912428855895996, Accuracy: 91.3690414428711
# Epoch 14, Loss: 0.4766705334186554, Accuracy: 91.53352355957031
# Epoch 15, Loss: 0.4577277898788452, Accuracy: 91.90946197509766
# Epoch 16, Loss: 0.4544192850589752, Accuracy: 92.14442443847656
# Epoch 17, Loss: 0.4327472150325775, Accuracy: 92.32064819335938
# Epoch 18, Loss: 0.4261332154273987, Accuracy: 92.44596099853516
# Epoch 19, Loss: 0.41868966817855835, Accuracy: 92.50077819824219
# Epoch 20, Loss: 0.4149847626686096, Accuracy: 92.55560302734375
# Epoch 21, Loss: 0.4109155237674713, Accuracy: 92.60651397705078
# Epoch 22, Loss: 0.4064543545246124, Accuracy: 92.6260986328125
# Epoch 23, Loss: 0.3983438313007355, Accuracy: 92.68091583251953
# Epoch 191, Loss: 0.015188906341791153, Accuracy: 99.78070068359375
# Epoch 192, Loss: 0.01483903732150793, Accuracy: 99.78070068359375
# Epoch 193, Loss: 0.01453718077391386, Accuracy: 99.80811309814453
# Epoch 194, Loss: 0.014360032044351101, Accuracy: 99.78853607177734
# Epoch 195, Loss: 0.014283495023846626, Accuracy: 99.78853607177734
# Epoch 196, Loss: 0.014031202532351017, Accuracy: 99.80419921875
# Epoch 197, Loss: 0.013128301128745079, Accuracy: 99.81202697753906
# Epoch 198, Loss: 0.01252740528434515, Accuracy: 99.81986236572266
# Epoch 199, Loss: 0.01218658871948719, Accuracy: 99.84727478027344
# Epoch 200, Loss: 0.012131749652326107, Accuracy: 99.83552551269531

# %%
for test_seq, test_labels in test_ds:
  prediction = test_step(model, test_seq)
  test_text = tokenizer.sequences_to_texts(test_seq.numpy())
  gt_text = tokenizer.sequences_to_texts(test_labels.numpy())
  texts = tokenizer.sequences_to_texts(prediction.numpy())
  print('-')
  print('q: ', test_text)
  print('a: ', gt_text)
  print('p: ', texts)
# Out:
# -
# q:  ['여기 기프티콘 되죠 \n']
# a:  ['\t 네 현금영수증 해드릴까 요 \n']
# p:  ['여기 진동 벨 가지 고 계시다가 울리면 주문 한 음료 가져가세요 \n']
# -
# q:  ['네 에 테이크 아웃 도 가능한가요 \n']
# a:  ['\t 네 로 오시 면 테이크 아웃 잔 에 담아 드려요 \n']
# p:  ['아뇨 현재 법적 으로 금지 하고 있어요 \n']
# -
# q:  ['아메리카노 톨 사이즈 로 주세요 \n']
# a:  ['\t 따뜻한 거 로 드릴 까요 \n']
# p:  ['사이즈 는 뭘 로 드릴 까요 \n']
# -
# q:  ['진동 을 따로 주시나요 \n']
# a:  ['\t 주 번호 로 드리겠습니다 \n']
# p:  ['네 그건 시즌 한정 메뉴 라 겨울 에는 판매 하지 않습니다 \n']
# -
# q:  ['자리 있나요 \n']
# a:  ['\t 네 있습니다 \n']
# p:  ['네 영수증 드릴게요 \n']
# -
# q:  ['그럼 루이보스 밀크 티 하나 \n']
# a:  ['\t 네 알겠습니다 \n']
# p:  ['네 알겠습니다 \n']
# -
# q:  ['다음 에 무료 로 하고 엔 도장 찍어주세요 \n']
# a:  ['\t 네 \n']
# p:  ['2 개 찍어 드렸고 진동 벨 로 알려 드리겠습니다 \n']
# -
# q:  ['아메리카노 한 잔 에 얼마 죠 \n']
# a:  ['\t 입니다 \n']
# p:  ['4000원 입니다 \n']
# -
# q:  ['얼마나 \n']
# a:  ['\t 바로 만들어 드릴게요 \n']
# p:  ['진동 벨 로 알려 드리겠습니다 \n']
# -
# q:  ['카푸치노 는 로 주시 고 아메리카노 는 로 \n']
# a:  ['\t 네 더 없으세요 \n']
# p:  ['드시고 가시나요 \n']
# -
# q:  ['아메리카노 는 어떤 종류 가 있나요 \n']
# a:  ['\t 디카 페인 과 기본 아메리카노 2 종류 있습니다 \n']
# p:  ['네 초코 머핀 이랑 치즈케이크 있습니다 \n']
# -
# q:  ['카카오 페이 로 결제 가능한가요 \n']
# a:  ['\t 네 가능합니다 \n']
# p:  ['네 자몽 에 이드 사이즈 업 가능해요 \n']
# -
# q:  ['오늘 의 커피 는 커피 로 하나요 맛 이 \n']
# a:  ['\t 아 네 오늘 은 과테말라 커피 입니다 \n']
# p:  ['네 저희 가게 마스코트 메뉴 에요 \n']
# -
# q:  ['머핀 은 뭐 가 제일 \n']
# a:  ['\t 블루베리 머핀 이 잘 나갑니다 \n']
# p:  ['초코 칩 쿠키 입니다 \n']
# -
# q:  ['현금 영수증 해주세요 \n']
# a:  ['\t 네 번호 찍어주세요 \n']
# p:  ['네 번호 찍어주세요 \n']
# -
# q:  ['둘 다 톨 사이즈 로 주세요 \n']
# a:  ['\t 여기 서 드시고 요 \n']
# p:  ['커피 는 따뜻하게 드릴 까요 \n']
# -
# q:  ['아이스 아메리카노 한 잔 가능한가요 \n']
# a:  ['\t 네 가능합니다 \n']
# p:  ['네 사이즈 는 어떤 걸 로 주문 넣어 드릴 까요 \n']
# -
# q:  ['아이스 아메리카노 에 샷 이 몇 개 \n']
# a:  ['\t 아이스 아메리카노 에 샷 은 개 \n']
# p:  ['네 더 필요한 거 없으신 가요 \n']
# -
# q:  ['카페라테 한 잔 주세요 \n']
# a:  ['\t 카페라테 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 카페라떼 컵 사이즈 는 뭘 로 드릴 까요 \n']
# -
# q:  ['아니요 \n']
# a:  ['\t 네 더 필요하신 건 없으신 가요 \n']
# p:  ['스콘 도 드시고 가시나요 \n']
# -
# q:  ['네 찍어주세요 \n']
# a:  ['\t 네 주문 딸기 스무디 와 쿠키 드릴게요 \n']
# p:  ['드시고 가세 요 \n']
# -
# q:  ['시즌 메뉴 오늘 도 가능한가요 \n']
# a:  ['\t 네 시즌 메뉴 가능합니다 \n']
# p:  ['네 다음 에 써도 됩니다 \n']
# -
# q:  ['시즌 메뉴 와 함께 되어 있는 세트 메뉴 가 있나요 \n']
# a:  ['\t 네 치즈 케이크 와 시즌 메뉴 두 잔 으로 세트 메뉴 있습니다 \n']
# p:  ['손잡이 있는 캐리어 에 담아 드리겠습니다 \n']
# -
# q:  ['라테 에 우유 두 도 변경 가능한가요 \n']
# a:  ['\t 네 라테 에 두유 로 변경 가능합니다 \n']
# p:  ['네 500원 추가 됩니다 \n']
# -
# q:  ['네 먹고 갈 거 예요 \n']
# a:  ['\t 카드 여기 주세요 \n']
# p:  ['그럼 머그잔 에 드릴게요 \n']
# -
# q:  ['카페인 이 음료 있나요 \n']
# a:  ['\t 티 음료 와 스무디 에는 카페인 이 않습니다 \n']
# p:  ['네 감사합니다 \n']
# -
# q:  ['딸기스무디 랑 키위 스무디 는 생 과일 인가요 \n']
# a:  ['\t 딸기 는 키위 는 생 과일 을 사용 하고 있습니다 \n']
# p:  ['500원 결제 해주시면 됩니다 \n']
# -
# q:  ['그럼 딸기 스무디 하나 주세요 \n']
# a:  ['\t 드시고 가시나요 \n']
# p:  ['아메리카노 원두 는 어떤 걸 로 할까 요 \n']
# -
# q:  ['아메리카노 한 잔이요 \n']
# a:  ['\t 아이스 아메리카노 로 드릴 까요 \n']
# p:  ['드시고 가시나요 \n']
# -
# q:  ['네 도 같이 \n']
# a:  ['\t 네 아메리카노 4000원 입니다 \n']
# p:  ['네 드시고 가실 건가 요 \n']
# -
# q:  ['디카 페인 아이스 아메리카노 한 잔 주세요 \n']
# a:  ['\t 디카 페인 아이스 아메리카노 는 기존 금액 에 300원 추가 되는데 괜찮으신 가요 \n']
# p:  ['드시고 가시나요 \n']
# -
# q:  ['커피 음료 것 뭐 가 있나요 \n']
# a:  ['\t 스무디 와 주스 있습니다 \n']
# p:  ['네 4500원 입니다 \n']
# -
# q:  ['주스 어떤 종류 있나요 \n']
# a:  ['\t 딸기 주스 주스 주스 가 있습니다 \n']
# p:  ['헤이즐넛 시럽 은 500원 추가 됩니다 \n']
# -
# q:  ['플랫 화이트 라지 로 주세요 \n']
# a:  ['\t 네 \n']
# p:  ['신 맛 과 고소한 맛 원두 중 에 어떤 걸 로 드릴 까요 \n']
# -
# q:  ['네 레드 벨벳 케이크 주세요 \n']
# a:  ['\t 음료 는 뭘 로 드릴 까요 \n']
# p:  ['드시고 가실 건가 요 \n']
# -
# q:  ['네 먹고 갈 거 예요 \n']
# a:  ['\t 유리잔 괜찮으세요 \n']
# p:  ['그럼 머그잔 에 드릴게요 \n']
# -
# q:  ['따뜻한 밀크 티 주세요 \n']
# a:  ['\t 네 \n']
# p:  ['4천원 입니다 \n']
# -
# q:  ['음료 얼마나 하나요 \n']
# a:  ['\t 10분 정도 주시 면 됩니다 \n']
# p:  ['따뜻한 거 맞으세요 \n']
# -
# q:  ['아이스 아메리카노 한잔 얼마 인가요 \n']
# a:  ['\t 4500원 입니다 \n']
# p:  ['9500원 입니다 \n']
# -
# q:  ['현금영수증 번호 \n']
# a:  ['\t 네 \n']
# p:  ['진동 벨 울리면 찾으러 오시 면 됩니다 \n']
# -
# q:  ['이 카드 로 결제 해주세요 \n']
# a:  ['\t 네 결제 도 와 드릴게요 \n']
# p:  ['네 감사합니다 \n']
# -
# q:  ['주문 한 게 다 안 \n']
# a:  ['\t 주 번호 가 몇 이 죠 \n']
# p:  ['네 총 9500원 결제 해드리겠습니다 \n']
# -
# q:  ['을 \n']
# a:  ['\t \n']
# p:  ['진동 벨 로 알려 드릴게요 \n']
# -
# q:  ['베이글 은 얼마 인가요 \n']
# a:  ['\t 베이글 은 2000원 입니다 \n']
# p:  ['베이글 과 동일하게 2000원 입니다 \n']
# -
# q:  ['지금 되나요 \n']
# a:  ['\t 는 계절 메뉴 라 지금 은 판매 하지 않습니다 \n']
# p:  ['네 다음 에 써도 됩니다 \n']
# -
# q:  ['바닐라 라테 는 따뜻하게 주세요 \n']
# a:  ['\t 네 적립 이나 할인 카드 있으세요 \n']
# p:  ['커피 는 시럽 은 넣어 드릴 까요 \n']
# -
# q:  ['테이크 아웃 으로 부탁드립니다 \n']
# a:  ['\t 결제 는 이 쪽 에서 도 와 드릴게요 \n']
# p:  ['아뇨 캐리어 에 2 개 이상 부터 가능해요 \n']
# -
# q:  ['혹시 테이크 아웃 잔 에 수 있나요 \n']
# a:  ['\t 테이크 아웃 하시는 건가 요 \n']
# p:  ['헤이즐넛 시럽 은 500원 추가 됩니다 \n']
# -
# q:  ['아메리카노 하나 는 샷 추가 해주세요 \n']
# a:  ['\t 아메리카노 는 둘 다 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 알겠습니다 \n']
# -
# q:  ['쿠폰 찍어주세요 \n']
# a:  ['\t 네 찍어 드릴게요 \n']
# p:  ['10 개 다모아 오시 면 커피한잔 드려요 \n']
# -
# q:  ['주문 할게요 \n']
# a:  ['\t 어떤 거 드릴 까요 \n']
# p:  ['결제 는 어떻게 도 와 드릴 까요 \n']
# -
# q:  ['파나요 \n']
# a:  ['\t 는 계절 지금 은 \n']
# p:  ['아뇨 현재 법적 으로 금지 하고 있어요 \n']
# -
# q:  ['그럼 겨울 메뉴 뭐 가 \n']
# a:  ['\t 겨울 엔 감귤 라테 가 제일 많이 나가요 \n']
# p:  ['와이파이 비밀번호 는 종이 에 써져있습니다 \n']
# -
# q:  ['네 결제 는 카드 로 할게요 \n']
# a:  ['\t 네 결제 완료 되었습니다 \n']
# p:  ['네 카드 랑 되었습니다 \n']
# -
# q:  ['둘 다 사이즈 로 할게요 \n']
# a:  ['\t 네 결제 는 어떤 것 으로 도 와 드릴 까요 \n']
# p:  ['포인트 적립 카드 드릴 까요 \n']
# -
# q:  ['기프티콘 으로 결제 할게요 \n']
# a:  ['\t 네 그럼 쿠폰 저 \n']
# p:  ['저 한테 보여주시고 제 가 확인 버튼 누르면 돼요 \n']
# -
# q:  ['녹차 라테 1 잔 주세요 \n']
# a:  ['\t 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 더 필요한 건 없으세요 \n']
# -
# q:  ['네 그럼 휘핑크림 추가 해서 주세요 \n']
# a:  ['\t 네 녹차 라테 에 휘핑크림 추가 해서 4500원 입니다 \n']
# p:  ['네 총 9500원 결제 해드리겠습니다 \n']
# -
# q:  ['브레드 종류 는 뭐 가 있나요 \n']
# a:  ['\t 허니 브레드 와 갈릭 치즈 브레드 가 있습니다 \n']
# p:  ['네 합쳐 드릴 까요 \n']
# -
# q:  ['생크림 이 건 어떤 건가 요 \n']
# a:  ['\t 허니 브레드 입니다 \n']
# p:  ['네 총 8000원 입니다 \n']
# -
# q:  ['네 그렇게 만들어 주세요 \n']
# a:  ['\t 더 필요한 건 없으세요 \n']
# p:  ['네 드시고 가시나요 \n']
# -
# q:  ['여기 있습니다 \n']
# a:  ['\t 네 확인 되셨고 되면 진동 벨 거 예요 \n']
# p:  ['손님 지금 15000 포인트 있으신 데 사용 해 드릴 까요 \n']
# -
# q:  ['핫초코 한 잔 아메리카노 사이 즈 업 한 잔 하면 얼마 인가요 \n']
# a:  ['\t 입니다 \n']
# p:  ['9500원 입니다 \n']
# -
# q:  ['주스 는 다른 건 없나요 \n']
# a:  ['\t 그럼 에 라테 추천 \n']
# p:  ['죄송합니다만 페퍼민트 는 방금 전 에 다 떨어졌어요 \n']
# -
# q:  ['그건 \n']
# a:  ['\t 네 만 따듯 해 요 \n']
# p:  ['진동 벨 울리면 찾으러 오시 면 됩니다 \n']
# -
# q:  ['통신사 할인 되죠 \n']
# a:  ['\t 네 300원 할인 됩니다 \n']
# p:  ['네 알겠습니다 \n']
# -
# q:  ['매장 에서 언제 까지 영업 하시나요 \n']
# a:  ['\t 오후 10시 까지 영업 입니다 \n']
# p:  ['네 있습니다 \n']
# -
# q:  ['아니요 그냥 주세요 \n']
# a:  ['\t 결제 해드릴게요 \n']
# p:  ['카페모카 5천 원 입니다 \n']
# -
# q:  ['가격 안 되나요 \n']
# a:  ['\t 한 해드릴게요 \n']
# p:  ['네 다음 에 써도 됩니다 \n']
# -
# q:  ['카페라테 한잔 주세요 \n']
# a:  ['\t 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 드시고 가시나요 \n']
# -
# q:  ['네 차가운 걸 로 주세요 \n']
# a:  ['\t 4500원 입니다 \n']
# p:  ['드시고 가시나요 \n']
# -
# q:  ['어떤 게 괜찮아요 \n']
# a:  ['\t 이나 원두 를 하시는 게 아니면 예 가체 많이 추천 \n']
# p:  ['머그잔 에 드릴게요 \n']
# -
# q:  ['그럼 추천 치즈 케이크 도 같이 주세요 \n']
# a:  ['\t 네 매장 에서 드시고 가시나요 \n']
# p:  ['네 더 필요한 거 없으신 가요 \n']
# -
# q:  ['그리고 휘핑크림 은 에스프레소 크림 으로 \n']
# a:  ['\t 결제 는 어떻게 해드릴까 요 \n']
# p:  ['네 알겠습니다 \n']
# -
# q:  ['지금 도 할인 하나요 \n']
# a:  ['\t 네 10시 까지 하고 있습니다 \n']
# p:  ['네 그럼 카페라떼 톨 사이즈 로 드리겠습니다 \n']
# -
# q:  ['그럼 와 아이스 아메리카노 로 할게요 \n']
# a:  ['\t 더 필요하신 건 없나요 \n']
# p:  ['아이스 아메리카노 한잔 주문 도 와 드리겠습니다 \n']
# -
# q:  ['네 할인 적립 은 \n']
# a:  ['\t 네 바코드 \n']
# p:  ['사용 하시고 잔액 3천 원 인데 충전 하시겠어요 \n']
# -
# q:  ['초코 프라푸치노 주세요 \n']
# a:  ['\t 휘핑 올려 드릴 까요 \n']
# p:  ['드시고 가시나요 \n']
# -
# q:  ['시럽 도 가 \n']
# a:  ['\t 드시고 가시나요 \n']
# p:  ['네 진동 벨 울리면 찾으러 오세요 \n']
# -
# q:  ['둘 다 사이즈 로 주세요 \n']
# a:  ['\t 드시고 가시나요 \n']
# p:  ['커피 는 따뜻하게 드릴 까요 \n']
# -
# q:  ['마시다가 갈 건데 테이크아웃 으로 주세요 \n']
# a:  ['\t 상 매장 에서는 머그컵 으로 드리고 있어요 \n']
# p:  ['현금영수증 해드릴까 요 \n']
# -
# q:  ['나갈 때 테이크아웃 컵 으로 수 있나요 \n']
# a:  ['\t 네 그렇게 해드릴게요 \n']
# p:  ['네 일회용 컵 에 담아 드리겠습니다 \n']
# -
# q:  ['아메리카노 두 잔 한잔 주세요 \n']
# a:  ['\t 드시고 가실 건가 요 \n']
# p:  ['네 아메리카노 어떤 걸 로 드릴 까요 \n']
# -
# q:  ['얼마나 하나요 \n']
# a:  ['\t 5분 정도 \n']
# p:  ['따뜻한 거 맞으세요 \n']
# -
# q:  ['포인트 적립 해주세요 \n']
# a:  ['\t 네 번호 입력 부탁드립니다 \n']
# p:  ['네 카드 카드 주시 면 도 와 드리겠습니다 \n']
# -
# q:  ['네 번호 로 할게요 \n']
# a:  ['\t 네 에 번호 \n']
# p:  ['드시고 가세 요 \n']
# -
# q:  ['아 포인트 포인트 사용 해주세요 \n']
# a:  ['\t 네 고객 님 포인트 총 있으신 데 사용 도 와 드리겠습니다 \n']
# p:  ['네 포인트 사용 가능하세요 \n']
# -
# q:  ['톨 사이즈 로 주문 할게요 \n']
# a:  ['\t 네 계산 도 와 드리겠습니다 \n']
# p:  ['네 더 필요한 거 없으신 가요 \n']
# -
# q:  ['아메리카노 사이즈 가능한가요 \n']
# a:  ['\t 네 500원 만 추가 하시면 가능하십니다 \n']
# p:  ['네 사이즈 업 도 와 드리겠습니다 \n']
# -
# q:  ['사이 즈 업 해서 주세요 \n']
# a:  ['\t 네 결제 는 어떻게 도 와 드릴 까요 \n']
# p:  ['네 음료 사이즈 는 어떤 걸 로 주문 넣어 드릴 까요 \n']
# -
# q:  ['커피 는 텀블러 에 담아주세요 \n']
# a:  ['\t 네 텀블러 할인 4000원 결제 도 와 드리겠습니다 \n']
# p:  ['텀블러 할인 300원 같이 해드릴게요 \n']
# -
# q:  ['아니요 아이스 로 주세요 \n']
# a:  ['\t 드시고 가실 건가 요 \n']
# p:  ['네 드시고 가시나요 \n']
# -
# q:  ['테이크아웃 할게요 \n']
# a:  ['\t 지금 중 인데 케이크 주문 하시면 아메리카노 한잔 로 드려요 \n']
# p:  ['결제 는 어떻게 도 와 드리겠습니다 \n']
# -
# q:  ['현금 결제 가 안 \n']
# a:  ['\t 현금 은 에서 주문 도 와 드리겠습니다 \n']
# p:  ['네 카드 받았습니다 \n']
# -
# q:  ['포인트 적립 되나요 \n']
# a:  ['\t 번호 포인트 적립 도 와 드리고 있어요 \n']
# p:  ['네 그렇습니다 \n']
# -
# q:  ['포인트 적립 할게요 \n']
# a:  ['\t 네 결제 되셨습니다 \n']
# p:  ['주차 는 하셨나요 \n']
# -
# q:  ['티라미수 는 있나요 \n']
# a:  ['\t 네 티라미수 는 있습니다 \n']
# p:  ['네 준비 해드리겠습니다 \n']
# -
# q:  ['네 현금영수증 해주세요 \n']
# a:  ['\t 네 드시고 가시나요 \n']
# p:  ['네 고객 님 결제 완료 되었습니다 \n']
# -
# q:  ['샷 추가 해주세요 \n']
# a:  ['\t 네 알겠습니다 \n']
# p:  ['네 알겠습니다 \n']
# -
# q:  ['얼마 에요 \n']
# a:  ['\t 만 원 입니다 \n']
# p:  ['총 7000원 입니다 \n']
# -
# q:  ['아이스 아메리카노 랑 샌드위치 주세요 \n']
# a:  ['\t 10시 에 세트 할인 가능하세요 \n']
# p:  ['준비 해드리겠습니다 \n']
